# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [10, 20, 40, 80, 160]
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(16, 16))

#OneMax
# MRPS
ax = axs[0][0]

# 1X
y1X = [30, 68, 214.4, 624, 2355.2]
y1X_sde = [11.2428, 8.39047, 37.9979, 96.2663, 458.662] # standard deviation
# UX
yUX = [21, 35.2, 55.2, 102.4, 152]
yUX_sde = [5.6745, 11.8727, 7.11056, 15.0944, 22.9085] # standard deviation

ax.errorbar(x, y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar(x, yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('MRPS of OneMax')
ax.legend()

# Evaluations
ax = axs[0][1]

# 1X
y1X = [235.52, 819.44, 3930.08, 17040.3, 94816]
y1X_sde = [82.3326, 96.0025, 594.003, 2290.2, 16182.1] # standard deviation
# UX
yUX = [149.68, 356.48, 797.4, 2097.12, 4414.88]
yUX_sde = [40.2743, 115.89, 89.1527, 288.937, 601.594] # standard deviation

ax.errorbar(x, y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar(x, yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('Evaluation of OneMax')
ax.legend()

### Trap5

# MRPS
ax = axs[1][0]

# 1X
y1X = [107.2, 265.6, 896, 3814.4]
y1X_sde = [22.6839, 52.6786, 202.386, 728.139] # standard deviation
# UX
yUX = [328, 3379.2]
yUX_sde = [67.5988, 862.838] # standard deviation

ax.errorbar([10,20,40,80], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('MRPS of Trap5')
ax.legend()

# Evaluations
ax = axs[1][1]

# 1X
y1X = [923.28, 3419.2, 17328, 109660]
y1X_sde = [179.363, 698.579, 3496.58, 20267.4] # standard deviation
# UX
yUX = [3704.8, 82106.9]
yUX_sde = [848.615, 20175.8] # standard deviation

ax.errorbar([10,20,40,80], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('Evaluation of Trap5')
ax.legend()


### leadingOnes

# MRPS
ax = axs[2][0]

# 1X
y1X = [113.6, 473.6, 3456]
y1X_sde = [29.6756, 34.4651, 575.288] # standard deviation
# UX
yUX = [71.6, 208, 726.4, 2508.8]
yUX_sde = [19.956, 35.0542, 135.802, 389.086] # standard deviation

ax.errorbar([10,20,40], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20, 40, 80], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('MRPS of LeadingOnes')
ax.legend()

# Evaluations
ax = axs[2][1]

# 1X
y1X = [968.24, 8100.48, 116498]
y1X_sde = [234.279, 752.764, 16193.8] # standard deviation
# UX
yUX = [600.4, 3174.08, 19376.3, 125398]
yUX_sde = [172.741, 497.534, 3462.57, 19119.3] # standard deviation

ax.errorbar([10,20, 40], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20, 40, 80], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('Evaluation of LeadingOnes')
ax.legend()

plt.show()

fig.savefig('visualize_plot.png', dpi=fig.dpi)
